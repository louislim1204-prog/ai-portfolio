# %% [markdown]
# <a href="https://colab.research.google.com/github/louislim1204-prog/ai-portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from collab")
# Out:
# Hello from collab
